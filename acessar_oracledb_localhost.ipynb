# %% [markdown]
# # Acessar BD Oracle Localhost

# %%
# Carregamento das Bibliotecas
import pandas as pd
import oracledb

# %%
try:
    oracledb.init_oracle_client(lib_dir="C:/oracle/instantclient")
except oracledb.ProgrammingError:
    pass  # Ignora erro caso já tenha sido chamado

# %%
# Configurar a conexão com o banco
conn = oracledb.connect(
    user="system",
    password="Duqueza1900",
    dsn="localhost/XE"  # Altere conforme seu banco (ex: "localhost/XE" para Oracle XE)
)

# %%
# Criar um cursor
cursor = conn.cursor()

# %%
# Testar conexão: listar todas as tabelas do usuário
cursor.execute("SELECT table_name FROM user_tables")
for row in cursor.fetchall():
    print(row)
# Out:
# ('LOGMNR_SESSION_EVOLVE$',)
# ('LOGMNR_GLOBAL$',)
# ('LOGMNR_PDB_INFO$',)
# ('LOGMNR_DID$',)
# ('LOGMNR_UID$',)
# ('LOGMNRGGC_GTLO',)
# ('LOGMNRGGC_GTCS',)
# ('LOGMNRC_DBNAME_UID_MAP',)
# ('LOGMNR_LOG$',)
# ('LOGMNR_PROCESSED_LOG$',)
# ('LOGMNR_SPILL$',)
# ('LOGMNR_AGE_SPILL$',)
# ('LOGMNR_RESTART_CKPT_TXINFO$',)
# ('LOGMNR_ERROR$',)
# ('LOGMNR_RESTART_CKPT$',)
# ('LOGMNR_FILTER$',)
# ('LOGMNR_SESSION_ACTIONS$',)
# ('LOGMNR_PARAMETER$',)
# ('LOGMNR_SESSION$',)
# ('LOGMNR_PROFILE_TABLE_STATS$',)
# ('LOGMNR_PROFILE_PLSQL_STATS$',)
# ('REDO_DB',)
# ('REDO_LOG',)
# ('ROLLING$CONNECTIONS',)
# ('ROLLING$DATABASES',)
# ('ROLLING$DIRECTIVES',)
# ('ROLLING$EVENTS',)
# ('ROLLING$PARAMETERS',)
# ('ROLLING$PLAN',)
# ('ROLLING$STATISTICS',)
# ('ROLLING$STATUS',)
# ('MVIEW$_ADV_WORKLOAD',)
# ('MVIEW$_ADV_BASETABLE',)
# ('MVIEW$_ADV_SQLDEPEND',)
# ('MVIEW$_ADV_PRETTY',)
# ('MVIEW$_ADV_TEMP',)
# ('MVIEW$_ADV_FILTER',)
# ('MVIEW$_ADV_LOG',)
# ('MVIEW$_ADV_FILTERINSTANCE',)
# ('MVIEW$_ADV_LEVEL',)
# ...

# %%
query = "SELECT * FROM vw_domicilios_quantidade_domicilios_consolidado"  # Substitua pelo nome da tabela
df = pd.read_sql(query, conn)

# Exibir as primeiras linhas
print(df.head())
# Out:
#       MUNICIPIO  TOTAL_DOMICILIOS
# 0    ACRELÂNDIA              2917
# 1  ASSIS BRASIL              1349
# 2     BRASILÉIA              5070
# 3        BUJARI              1776
# 4      CAPIXABA              2213
# C:\Users\Teletrabalho\AppData\Local\Temp\ipykernel_10644\633474057.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
